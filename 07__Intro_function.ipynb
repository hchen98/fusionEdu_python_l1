# %%
print("Hooray!")
# Out:
# Hooray!

# %% [markdown]
# # Function
#
# What is a function?

# %% [markdown]
# <i>def</i> as define.

# %%
def check():
    print("Hooray!")

print("Hooray!")
# Out:
# Hooray!

# %%
def check():
    # beginning of funtion body
    
    print("Hooray!")
    
    # ending of function body
# From this line of code, it will not be part of 
# "check" function body since it is not indented with a tab



print("Hooray!")
check()
# Out:
# Hooray!
# Hooray!

# %% [markdown]
# ![4b8c07aa-d067-4922-b5ac-79436116b109.png](attachment:4b8c07aa-d067-4922-b5ac-79436116b109.png)

# %% [markdown]
# Visualization: <a href="https://pythontutor.com/render.html#code=def%20check%28%29%3A%0A%20%20%20%20print%28%22Hooray!%22%29%0A%0Aprint%28%22Hooray!%22%29%0Acheck%28%29&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false">here</a>

# %% [markdown]
# # <i>Return</i>
#
# <i>return</i>

# %%
def check():
    return "Hooray!"

    

print("Hooray!")
print(check())
# Out:
# Hooray!
# Hooray!

# %% [markdown]
# Visualization: <a href="https://pythontutor.com/render.html#code=def%20check%28%29%3A%0A%20%20%20%20return%20%22Hooray!%22%0A%0A%20%20%20%20%0A%0Aprint%28%22Hooray!%22%29%0Aprint%28check%28%29%29&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false">here</a>
#
# With a return, it will always be the very end (the last line of code) of the function body!

# %% [markdown]
# Take a guess, will the following code print 123?

# %%
def check():
    return "Hooray!"
    print("123")

    

print("Hooray!")
# print(check())
# Out:
# Hooray!

# %% [markdown]
# # Parameter
#
# Sometimes, a function may accept a parameter(s).
#
# Let's take an example of a function that calculates the area of a triangle:
#
# $\Large A = \frac{1}{2}bh$

# %% [markdown]
# ![function_1.png](attachment:function_1.png)

# %%
def triangle_area(b, h):
    area = (1/2) * b * h
    return area

print(triangle_area(5, 3))
# Out:
# 7.5

# %% [markdown]
# Therefore, $\Large A$ is the output of the function (LHS), while $\Large \frac{1}{2}bh$ is a function (RHS).

# %%
# alternatively it can be rewritten as:
def triangle_area(b, h):
    return (1/2) * b * h

print(triangle_area(5, 3))
# Out:
# 7.5
