# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Fusion-Education" data-toc-modified-id="Fusion-Education-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Fusion Education</a></span></li><li><span><a href="#Data-Structures" data-toc-modified-id="Data-Structures-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data Structures</a></span><ul class="toc-item"><li><span><a href="#set" data-toc-modified-id="set-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>set</a></span></li><li><span><a href="#set()" data-toc-modified-id="set()-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>set()</a></span></li></ul></li><li><span><a href="#dictionary" data-toc-modified-id="dictionary-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>dictionary</a></span></li></ul></div>

# %% [markdown]
# # Fusion Education
#
# - Instructor: Hui (Henry) Chen and Peggy
# - Time: Saturday 11:30 AM - 12:30 PM
# - Python version: 3.9.x
#
# <u>Topics</u>:
# 1. Review
# 2. Data Structures:
#     - set
#     - dictionary
#
#
# <b>Heads Up!</b> For the <u>data structure</u> and <u>flow control</u> sections, at some point we will use a website to visualize the code. Link: https://pythontutor.com/visualize.html#mode=edit
#
# # Data Structures
#
# ## set
#
# Very similar as list except you <b>cannot</b> have duplicate element(s)!
#
# <b>Properties</b>:
# - Unordered
# - Changeable
# - <b>Not allow duplicate elements</b>
# - <b>Always separated by a comma between each elements</b>

# %%
set1 = {"book1", "book2", "book3", "book4", "book5", "book6", "book7"}

# %%
print(type(set1))
# Out:
# <class 'set'>

# %%
set2 = {"book1", "book3", "book3"}

# %%
# print(set2)

# %% [markdown]
# $
# \large \text{Unfortunately, set does not accept indexing 😔}
# $

# %%
set1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 set1[0]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# ## set()
#
# <b>When we create a set through set() method, we need to have extract parentheses inside the parentheses!</b>
#
# $
# \Large \text{set((element1, element2, element3, ...))}
# $

# %%
set3 = set((9, 8, 7, 6, 5, 4, 3, 2, 1))
print(type(set3))
# Out:
# <class 'set'>

# %% [markdown]
# # dictionary
#
# In the real world, we have a dictionary (see image below) where a single word holds/contains multiple information at once.
#
# ![dict_1.jpg](attachment:dict_1.jpg)

# %% [markdown]
# <b>Good news! We can do the same in Python!</b>

# %% [markdown]
# ![dict_2.png](attachment:dict_2.png)

# %% [markdown]
# ![dict_3.png](attachment:dict_3.png)

# %% [markdown]
# With dictionary data type, we always have key and value pair, and the key must be <b>unique</b>!

# %%
python_class1 = {
    "student_1": "Nuoyu",
    "student_2": "Leo",
    "student_3": "JunRen",
    "student_4": "Whilliam",
    "student_5": "Daniel",
    "student_6": "Whilliam"
}

print(python_class1)
# Out:
# {'student_1': 'Nuoyu', 'student_2': 'Leo', 'student_3': 'JunRen', 'student_4': 'Whilliam', 'student_5': 'Daniel', 'student_6': 'Whilliam'}

# %% [markdown]
# Alternately, we can use for loop to print it!

# %%
for key, val in python_class1.items():
    print(f"{key}: {val}")
# Out:
# student_1: Nuoyu
# student_2: Leo
# student_3: JunRen
# student_4: Whilliam
# student_5: Daniel
# student_6: Whilliam

# %%
print(python_class1["student_4"])
# Out:
# Whilliam

# %%
print(python_class1["student_6"])
# Out:
# Whilliam

# %% [markdown]
# Let's try when we have duplicate keys.

# %%
python_class2 = {
    "student_1": "Nuoyu",
    "student_1": "Leo",
    "student_3": "JunRen",
    "student_4": "Whilliam",
    "student_5": "Daniel",
    "student_6": "Whilliam"
}

print(python_class2)
# Out:
# {'student_1': 'Leo', 'student_3': 'JunRen', 'student_4': 'Whilliam', 'student_5': 'Daniel', 'student_6': 'Whilliam'}

# %%
for key, val in python_class2.items():
    print(f"{key}: {val}")
# Out:
# student_1: Leo
# student_3: JunRen
# student_4: Whilliam
# student_5: Daniel
# student_6: Whilliam

# %% [markdown]
# Note, the key and value can be different data types (integer, float, boolean, and string) as we wish!

# %%
dictionary1 = {
    0: "Hello World!",
    "Name": False,
    True: 1,
    0.22: 0.33
}

# %%
print(dictionary1)
# Out:
# {0: 'Hello World!', 'Name': False, True: 1, 0.22: 0.33}

# %%
for key, val in dictionary1.items():
    print(f"{key}: {val}")
# Out:
# 0: Hello World!
# Name: False
# True: 1
# 0.22: 0.33
